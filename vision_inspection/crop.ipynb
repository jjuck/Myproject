# %%
import os
import cv2
import numpy as np

def save_cropped_image(image, file_path, output_folder, crop_number):
    """크롭된 이미지를 지정된 폴더에 저장"""
    os.makedirs(output_folder, exist_ok=True)  # 폴더가 없으면 생성
    base_name = os.path.basename(file_path).split('.')[0]
    output_path = os.path.join(output_folder, f"{base_name}_crop{crop_number}.jpeg")
    cv2.imwrite(output_path, image)
    print(f"크롭된 이미지 저장 완료: {output_path}")

def find_and_save_cropped_images_in_folder(folder_path, master_image_path, threshold=0.7):
    # 마스터 이미지 로드 및 그레이스케일 변환
    master_image = cv2.imread(master_image_path, cv2.IMREAD_GRAYSCALE)
    if master_image is None:
        print("마스터 이미지를 로드할 수 없습니다.")
        return
    
    master_height, master_width = master_image.shape[:2]
    output_folder = f"{folder_path}_crops"  # 결과 저장 폴더

    # 단일 폴더 내 모든 이미지 파일 처리
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)

        if file_name.endswith((".jpeg", ".jpg", ".png")):
            image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
            if image is None:
                print(f"이미지를 로드할 수 없습니다: {file_path}")
                continue

            # 이미지가 마스터 이미지보다 작으면 매칭을 건너뜀
            if image.shape[0] < master_height or image.shape[1] < master_width:
                print(f"이미지가 마스터 이미지보다 작아서 스킵됨: {file_path}")
                continue

            # 템플릿 매칭 수행
            result = cv2.matchTemplate(image, master_image, cv2.TM_CCOEFF_NORMED)
            _, max_val, _, max_loc = cv2.minMaxLoc(result)

            # 임계값 이상인 경우 크롭하여 저장
            if max_val >= threshold:
                top_left = max_loc
                bottom_right = (top_left[0] + master_width, top_left[1] + master_height)
                cropped_image = image[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]]
                save_cropped_image(cropped_image, file_path, output_folder, crop_number=1)
            else:
                print(f"임계값 미만으로 제외됨: {file_path}, 유사도: {max_val}")

# 사용 예시
master_image_path = '160_master.jpeg'  # 마스터 이미지 경로
folder_path = '166_pass'  # 단일 폴더 경로

find_and_save_cropped_images_in_folder(folder_path, master_image_path)
# Out:
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000001(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000003(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000004(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000005(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000006(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000007(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000008(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000009(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000010(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000012(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000013(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000014(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000015(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000016(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000017(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000018(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000019(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000020(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000021(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000022(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000023(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000024(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000025(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000026(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000027(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000028(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000029(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000030(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000031(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000032(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000033(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000034(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000035(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000036(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000037(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000038(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000039(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000040(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000041(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000042(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000043(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000044(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000045(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000047(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000048(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000049(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000050(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000051(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000052(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000053(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000054(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000055(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000056(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000057(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000058(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000059(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000060(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000061(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000062(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000063(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000064(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000065(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000066(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000067(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000068(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000069(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000070(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000071(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000072(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000073(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000074(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000075(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000076(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000077(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000078(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000079(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000080(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000081(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000082(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000083(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000084(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000085(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000086(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000087(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000088(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000089(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000090(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000091(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000092(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000093(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000094(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000095(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000096(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000097(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000098(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000099(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000100(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000101(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000102(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000103(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000104(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000105(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000106(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000107(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000108(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000109(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000110(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000111(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000112(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000113(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000114(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000115(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000116(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000117(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000118(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000119(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000120(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000121(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000122(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000123(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000124(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000125(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000126(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000127(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000128(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000129(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000130(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000131(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000132(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000133(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000134(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000135(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000136(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000137(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000138(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000139(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000140(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000141(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000142(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000143(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000144(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000145(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000146(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000147(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000148(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000149(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000150(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000151(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000152(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000153(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000154(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000155(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000156(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000157(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000158(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000159(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000160(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000161(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000162(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000163(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000164(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000165(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000166(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000167(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000168(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000169(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000170(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000171(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000172(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000173(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000174(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000175(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000176(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000177(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000178(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000179(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000180(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000181(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000182(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000183(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000184(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000187(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000188(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000189(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000190(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000191(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000192(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000193(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000194(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000195(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000196(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000197(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000198(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000199(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000200(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000201(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000202(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000203(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000204(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000205(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000206(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000207(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000208(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000209(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000210(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000211(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000212(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000213(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000214(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000215(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000216(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000217(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000218(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000219(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000220(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000221(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000222(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000223(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000224(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000225(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000226(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000227(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000228(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000229(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000230(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000231(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000232(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000233(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000234(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000235(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000236(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000237(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000238(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000239(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000240(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000241(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000242(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000243(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000244(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000245(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000246(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000247(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000248(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000249(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000250(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000252(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000253(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000254(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000255(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000256(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000257(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000258(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000259(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000260(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000261(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000262(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000263(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000264(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000265(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000266(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000267(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000268(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000269(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000272(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000273(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000274(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000275(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000276(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000278(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000279(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000281(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000282(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000283(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000284(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000285(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000287(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000288(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000289(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000290(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000292(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000293(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000295(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000297(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000298(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000299(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000300(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000301(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000302(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000303(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000304(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000305(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000306(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000307(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000308(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000309(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000310(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000311(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000312(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000313(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000314(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000315(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000316(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000317(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000318(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000319(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000320(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000321(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000322(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000323(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000324(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000325(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000326(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000327(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000328(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000329(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000330(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000331(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000332(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000333(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000334(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000335(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000336(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000337(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000338(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000339(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000340(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000341(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000342(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000343(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000344(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000345(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000346(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000347(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000348(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000349(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000350(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000351(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000352(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000354(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000355(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000356(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000357(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000358(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000359(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000360(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000361(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000362(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000363(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000364(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000365(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000366(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000367(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000368(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000369(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000370(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000371(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000372(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000373(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000374(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000375(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000376(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000377(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000378(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000379(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000380(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000381(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000382(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000383(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000384(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000385(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000386(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000387(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000388(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000389(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000390(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000392(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000393(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000394(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000396(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000397(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000398(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000399(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000400(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000401(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000402(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000403(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000404(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000405(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000406(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000408(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000409(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000411(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000412(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000413(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000414(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000415(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000416(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000418(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000419(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000420(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000421(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000422(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000423(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000424(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000425(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000426(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000427(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000428(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000429(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000430(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000431(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000433(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000434(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000435(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000437(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000438(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000439(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000441(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000442(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000443(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000444(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000445(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000446(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000447(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000448(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000449(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000450(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000451(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000453(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000454(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000455(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000456(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000457(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000458(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000459(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000460(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000461(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000462(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000463(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000464(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000465(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000467(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000468(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000469(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000470(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000471(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000473(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000474(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000475(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000476(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000477(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000478(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000479(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000480(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000481(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000482(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000483(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000484(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000485(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000486(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000488(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000489(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000490(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000491(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000492(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000493(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000496(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000497(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000498(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000499(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000500(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000501(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000502(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000503(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000504(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000505(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000507(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000508(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000509(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000510(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000511(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000512(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000513(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000514(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000515(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000516(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000517(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000518(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000519(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000520(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000521(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000522(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000523(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000524(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000525(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000526(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000527(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000529(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000530(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000531(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000532(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000533(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000534(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000535(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000536(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000538(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000539(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000540(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000541(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000542(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000543(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000544(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000545(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000546(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000547(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000550(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000551(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000552(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000553(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000554(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000555(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000556(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000557(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000558(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000559(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000560(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000561(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000562(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000563(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000564(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000565(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000566(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000568(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000571(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000572(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000574(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000576(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000577(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000578(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000581(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000582(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000583(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000584(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000585(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000587(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000588(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000589(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000590(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000591(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000593(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000594(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000595(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000596(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000597(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000598(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000599(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000600(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000601(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000603(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000605(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000606(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000607(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000609(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000611(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000613(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000614(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000615(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000616(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000617(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000618(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000619(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000620(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000621(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000622(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000623(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000625(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000626(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000627(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000628(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000629(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000630(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000631(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000632(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000633(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000634(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000635(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000636(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000637(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000639(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000640(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000641(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000642(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000643(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000644(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000645(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000647(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000648(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000649(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000650(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000651(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000652(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000653(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000654(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000655(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000657(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000658(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000659(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000660(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000661(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000662(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000663(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000665(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000666(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000667(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000668(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000669(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000670(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000671(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000672(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000673(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000674(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000675(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000676(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000677(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000678(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000679(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000680(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000681(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000682(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000683(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000684(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000685(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000686(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000687(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000688(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000689(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000690(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000691(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000692(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000693(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000694(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000695(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000696(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000697(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000698(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000699(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000700(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000701(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000702(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000703(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000704(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000705(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000706(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000707(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000708(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000709(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000710(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000711(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000712(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000713(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000714(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000715(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000716(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000717(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000718(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000719(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000720(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000721(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000722(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000723(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000724(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000725(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000726(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000727(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000728(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000729(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000730(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000731(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000732(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000733(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000734(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000735(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000736(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000737(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000738(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000739(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000740(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000741(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000742(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000743(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000744(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000745(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000746(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000748(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000749(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000750(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000751(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000752(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000753(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000754(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000755(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000756(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000757(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000758(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000759(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000760(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000761(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000762(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000763(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000764(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000765(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000766(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000767(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000768(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000769(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000770(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000771(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000772(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000773(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000774(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000775(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000776(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000777(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000778(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000779(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000780(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000781(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000782(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000783(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000784(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000785(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000786(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000787(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000788(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000789(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000790(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000791(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000792(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000793(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000794(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000795(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000796(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000797(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000798(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000799(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000800(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000801(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000802(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000803(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000804(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000805(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000806(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000807(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000808(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000809(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000810(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000811(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000812(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000813(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000814(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000815(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000816(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000817(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000818(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000819(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000820(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000821(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000822(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000823(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000824(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000826(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000827(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000828(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000829(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000830(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000831(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000832(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000833(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000834(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000835(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000836(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000837(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000838(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000839(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000840(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000841(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000842(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000843(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100000844(1)_crop1.jpeg
# 크롭된 이미지 저장 완료: 166_pass_crops\EBB100